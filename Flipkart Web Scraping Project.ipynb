# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def extract_product_data(new_soup):
    """
    Extracts all relevant product information in one pass through the soup object
    to minimize time complexity.
    """
    product_data = {}

    try:
        # Get Product Name
        product_name = new_soup.find('span', attrs={'class': 'VU-ZEz'})
        product_data["Product Name"] = product_name.text.strip() if product_name else "NA"
        
        # Get Original Price
        original_price = new_soup.find('div', class_='yRaY8j A6+E6v')
        product_data["Original Price"] = int(original_price.text.strip().replace('₹', '').replace(',', '')) if original_price else 0
        
        # Get Discounted Price
        discounted_price = new_soup.find('div', class_='Nx9bqj CxhGGd')
        product_data["Discounted Price"] = int(discounted_price.text.strip().replace('₹', '').replace(',', '')) if discounted_price else 0
        
        # Get Extra Off Value
        extra_off = new_soup.find('div', class_='_2lX4N0')
        product_data["Extra Off"] = int(extra_off.span.text.replace('Extra ₹', '').replace('off', '').strip()) if extra_off and extra_off.span else 0
        
        # Get Discount Percentage
        discount_percent = new_soup.find('div', class_='UkUFwK WW8yVX')
        product_data["Discount Percentage"] = int(discount_percent.span.text.replace('% off', '').strip()) / 100 if discount_percent and discount_percent.span else 0
        
        # Get Overall Rating
        overall_rating = new_soup.find('div', class_='ipqd2A')
        product_data["Overall Rating"] = overall_rating.text.strip() if overall_rating else "N/A"
        
        # Get Ratings by Category
        ratings = {}
        for item in new_soup.find_all('a', class_='col-3-12'):
            category = item.find('div', class_='NTiEl0')
            rating_value = item.find('text', class_='_2DdnFS')
            if category and rating_value:
                ratings[category.text.strip()] = rating_value.text.strip()
        product_data.update(ratings)
    
    except Exception as e:
        print(f"Error extracting product data: {e}")
    
    return product_data  # Added return statement

def extract_specific_product_details(new_soup):
    """
    Extracts only the required product details from the table.
    """
    # Initialize product data with default "N/A" values
    product_data = {
        "In The Box": "N/A",
        "Model Number": "N/A",
        "Model Name": "N/A",
        "Color": "N/A",
        "Display Size": "N/A",
        "Resolution": "N/A",
        "GPU": "N/A",
        "Display Type": "N/A",
        "Operating System": "N/A",
        "Processor Brand": "N/A",
        "Processor Type": "N/A",
        "Processor Core": "N/A",
        "Internal Storage": "N/A",
        "RAM": "N/A",
        "Expandable Storage": "N/A",
        "Primary Camera": "N/A",
        "Secondary Camera": "N/A",
        "Network Type": "N/A",
        "Battery Capacity": "N/A",
        "Depth": "N/A",
        "Weight": "N/A"
    }

    try:
        # Get Product Details (from table)
        rows = new_soup.find_all('tr', class_='WJdYP6 row')
        for row in rows:
            key = row.find('td', class_='+fFi1w col col-3-12')
            value = row.find('td', class_='Izz52n col col-9-12')

            if key and value:
                key_text = key.text.strip()
                value_text = value.text.strip()

                # Update product data only if the key matches required fields
                if key_text in product_data:
                    product_data[key_text] = value_text

    except Exception as e:
        print(f"Error extracting specific product details: {e}")

    return product_data  # Make sure the return statement is placed here

# %%
if __name__ == '__main__':
    # User agent headers for web scraping
    HEADERS = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36",
        "Accept-Language": "en-US, en;q=0.5"
    }

    # The webpage URL (start with page 1)
    BASE_URL = "https://www.flipkart.com/q/5g-mobiles-under-30000?page="
    
    # Make initial request to fetch first page and check how many total pages exist
    webpage = requests.get(BASE_URL + "1", headers=HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Extract total number of pages from the pagination info
    page_info = soup.find('div', attrs={'class': '_1G0WLw'}).find('span').text.strip()
    parts = page_info.split()
    total_pages = int(parts[3])  # Get total number of pages (e.g., 420)
    print("Total No. of Pages: ", total_pages)

    # Initialize list to hold all products' data
    all_products = []

    # Loop over a limited number of pages for efficiency
    for page in range(1, 42):  # Change to (1, total_pages + 1) for full scrape
        print(f"Scraping Page {page}...")

        # Make request for each page
        try:
            webpage = requests.get(BASE_URL + str(page), headers=HEADERS)
            soup = BeautifulSoup(webpage.content, "html.parser")

            # Extract all product links on the current page
            links_list = [link.get('href') for link in soup.find_all('a', attrs={'class': 'CGtC98'})]
            print(f"--> Found {len(links_list)} product links on Page {page}")

            # Loop over each product link and fetch product details
            for i, link in enumerate(links_list):
                product_url = "https://www.flipkart.com" + link
                new_webpage = requests.get(product_url, headers=HEADERS)
                new_soup = BeautifulSoup(new_webpage.content, "html.parser")

                # Extract product data in one pass
                product_data = extract_product_data(new_soup)
                product_detail = extract_specific_product_details(new_soup)

                # Merge the product data and specific details into one dictionary
                merged_product_data = {**product_data, **product_detail}
                all_products.append(merged_product_data)
                
                print(f"Link No: {i + 1} processed...")

            print(f"Page No: {page} successfully scraped...")
            print("*" * 50)

        except requests.exceptions.RequestException as e:
            print(f"Request failed: {e}")
            continue  # Skip to the next page if there's a request error

    # Create a DataFrame from the list of product dictionaries
    Flipkart_df = pd.DataFrame(all_products)
    Flipkart_df

    # Output DataFrame to CSV
#     Flipkart_df.to_csv("flipkart_5g_mobiles.csv", index=False)
#     print("Data saved to 'flipkart_5g_mobiles.csv'")
# Out:
# Total No. of Pages:  428
# Scraping Page 1...
# --> Found 24 product links on Page 1
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 1 successfully scraped...
# **************************************************
# Scraping Page 2...
# --> Found 24 product links on Page 2
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 2 successfully scraped...
# **************************************************
# Scraping Page 3...
# --> Found 24 product links on Page 3
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 3 successfully scraped...
# **************************************************
# Scraping Page 4...
# --> Found 24 product links on Page 4
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 4 successfully scraped...
# **************************************************
# Scraping Page 5...
# --> Found 24 product links on Page 5
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 5 successfully scraped...
# **************************************************
# Scraping Page 6...
# --> Found 24 product links on Page 6
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 6 successfully scraped...
# **************************************************
# Scraping Page 7...
# --> Found 24 product links on Page 7
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 7 successfully scraped...
# **************************************************
# Scraping Page 8...
# --> Found 24 product links on Page 8
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 8 successfully scraped...
# **************************************************
# Scraping Page 9...
# --> Found 24 product links on Page 9
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 9 successfully scraped...
# **************************************************
# Scraping Page 10...
# --> Found 24 product links on Page 10
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 10 successfully scraped...
# **************************************************
# Scraping Page 11...
# --> Found 24 product links on Page 11
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 11 successfully scraped...
# **************************************************
# Scraping Page 12...
# --> Found 24 product links on Page 12
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 12 successfully scraped...
# **************************************************
# Scraping Page 13...
# --> Found 24 product links on Page 13
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 13 successfully scraped...
# **************************************************
# Scraping Page 14...
# --> Found 24 product links on Page 14
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 14 successfully scraped...
# **************************************************
# Scraping Page 15...
# --> Found 24 product links on Page 15
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 15 successfully scraped...
# **************************************************
# Scraping Page 16...
# --> Found 24 product links on Page 16
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 16 successfully scraped...
# **************************************************
# Scraping Page 17...
# --> Found 24 product links on Page 17
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Request failed: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Scraping Page 18...
# --> Found 24 product links on Page 18
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 18 successfully scraped...
# **************************************************
# Scraping Page 19...
# --> Found 24 product links on Page 19
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 19 successfully scraped...
# **************************************************
# Scraping Page 20...
# --> Found 24 product links on Page 20
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Error extracting product data: invalid literal for int() with base 10: 'Special price'
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 20 successfully scraped...
# **************************************************
# Scraping Page 21...
# --> Found 24 product links on Page 21
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 21 successfully scraped...
# **************************************************
# Scraping Page 22...
# --> Found 24 product links on Page 22
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 22 successfully scraped...
# **************************************************
# Scraping Page 23...
# --> Found 24 product links on Page 23
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 23 successfully scraped...
# **************************************************
# Scraping Page 24...
# --> Found 24 product links on Page 24
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 24 successfully scraped...
# **************************************************
# Scraping Page 25...
# --> Found 24 product links on Page 25
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 25 successfully scraped...
# **************************************************
# Scraping Page 26...
# --> Found 24 product links on Page 26
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 26 successfully scraped...
# **************************************************
# Scraping Page 27...
# --> Found 24 product links on Page 27
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 27 successfully scraped...
# **************************************************
# Scraping Page 28...
# --> Found 24 product links on Page 28
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 28 successfully scraped...
# **************************************************
# Scraping Page 29...
# --> Found 24 product links on Page 29
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 29 successfully scraped...
# **************************************************
# Scraping Page 30...
# --> Found 24 product links on Page 30
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 30 successfully scraped...
# **************************************************
# Scraping Page 31...
# --> Found 24 product links on Page 31
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 31 successfully scraped...
# **************************************************
# Scraping Page 32...
# --> Found 24 product links on Page 32
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 32 successfully scraped...
# **************************************************
# Scraping Page 33...
# --> Found 24 product links on Page 33
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 33 successfully scraped...
# **************************************************
# Scraping Page 34...
# --> Found 24 product links on Page 34
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 34 successfully scraped...
# **************************************************
# Scraping Page 35...
# --> Found 24 product links on Page 35
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 35 successfully scraped...
# **************************************************
# Scraping Page 36...
# --> Found 24 product links on Page 36
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 36 successfully scraped...
# **************************************************
# Scraping Page 37...
# --> Found 24 product links on Page 37
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 37 successfully scraped...
# **************************************************
# Scraping Page 38...
# --> Found 24 product links on Page 38
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 38 successfully scraped...
# **************************************************
# Scraping Page 39...
# --> Found 24 product links on Page 39
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 39 successfully scraped...
# **************************************************
# Scraping Page 40...
# --> Found 24 product links on Page 40
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 40 successfully scraped...
# **************************************************
# Scraping Page 41...
# --> Found 24 product links on Page 41
# Link No: 1 processed...
# Link No: 2 processed...
# Link No: 3 processed...
# Link No: 4 processed...
# Link No: 5 processed...
# Link No: 6 processed...
# Link No: 7 processed...
# Link No: 8 processed...
# Link No: 9 processed...
# Link No: 10 processed...
# Link No: 11 processed...
# Link No: 12 processed...
# Link No: 13 processed...
# Link No: 14 processed...
# Link No: 15 processed...
# Link No: 16 processed...
# Link No: 17 processed...
# Link No: 18 processed...
# Link No: 19 processed...
# Link No: 20 processed...
# Link No: 21 processed...
# Link No: 22 processed...
# Link No: 23 processed...
# Link No: 24 processed...
# Page No: 41 successfully scraped...
# **************************************************

# %%
Flipkart_df
# Out:
#                                           Product Name  Original Price  \
# 0    OPPO K12x 5G with 45W SUPERVOOC Charger In-The...           16999
# 1    Nothing Phone (2a) Plus (Grey, 256 GB)  (12 GB...           31999
# 2    Motorola Edge 50 Pro 5G with 125W Charger (Lux...           41999
# 3    Motorola Edge 50 Pro 5G with 125W Charger (Moo...           41999
# 4    CMF by Nothing Phone 1 (Orange, 128 GB)  (8 GB...           21999
# ..                                                 ...             ...
# 966               Apple iPhone 16 Plus (White, 128 GB)               0
# 967  Tecno Pova 5 Pro 5G (Silver Fantasy, 256 GB)  ...           20999
# 968        Xiaomi 14 (Jade Green, 512 GB)  (12 GB RAM)           79999
# 969   vivo Y28 5G (Crystal Purple, 128 GB)  (6 GB RAM)           19999
# 970     realme 11 5G (Glory Black, 128 GB)  (8 GB RAM)           20999
#
#      Discounted Price  Extra Off  Discount Percentage Overall Rating Camera  \
# 0               12999     4000.0                 0.23            4.5    3.9
# 1               25999     6000.0                 0.18            4.4    4.0
# 2               29999     6000.0                 0.28            4.4    4.3
# 3               29999    12000.0                 0.28            4.4    4.3
# 4               16499     1500.0                 0.25            4.4    3.8
# ..                ...        ...                  ...            ...    ...
# 966             89900        0.0                 0.00            4.7    4.8
# 967             15990        0.0                 0.23            4.2    3.9
# 968             59999    20000.0                 0.25            4.5    4.6
# 969             14999        0.0                 0.25            4.3    4.1
# 970             13299     5700.0                 0.36            4.3    4.1
#
#     Battery Display Design  ... Processor Core Internal Storage    RAM  \
# 0       4.4     4.2    4.4  ...      Octa Core           128 GB   6 GB
# 1       4.1     4.3    4.4  ...      Octa Core           256 GB  12 GB
# 2       4.0     4.5    4.5  ...      Octa Core           256 GB  12 GB
# 3       4.0     4.5    4.5  ...      Octa Core           256 GB  12 GB
# 4       4.2     4.3    4.4  ...      Octa Core           128 GB   8 GB
# ..      ...     ...    ...  ...            ...              ...    ...
# 966     4.6     4.8    4.7  ...      Hexa Core           128 GB    N/A
# 967     3.9     4.1    4.3  ...            N/A           256 GB   8 GB
# 968     4.1     4.6    4.7  ...      Octa Core           512 GB  12 GB
# 969     4.2     4.2    4.3  ...      Octa Core           128 GB   6 GB
# 970     4.1     4.1    4.2  ...      Octa Core           128 GB   8 GB
#
#     Expandable Storage      Primary Camera   Secondary Camera  \
# 0                 1 TB          32MP + 2MP   8MP Front Camera
# 1                  N/A         50MP + 50MP  50MP Front Camera
# 2                  N/A  50MP + 13MP + 10MP  50MP Front Camera
# 3                  N/A  50MP + 13MP + 10MP  50MP Front Camera
# 4                 2 TB          50MP + 2MP  16MP Front Camera
# ..                 ...                 ...                ...
# 966                N/A         48MP + 12MP  12MP Front Camera
# 967               1 TB       50MP + 0.08MP  16MP Front Camera
# 968                N/A  50MP + 50MP + 50MP  32MP Front Camera
# 969               1 TB          50MP + 2MP   8MP Front Camera
# 970               2 TB         108MP + 2MP  16MP Front Camera
#
#                  Network Type Battery Capacity    Depth Weight
# 0              5G, 4G, 3G, 2G         5100 mAh  7.68 mm  186 g
# 1              5G, 4G, 3G, 2G         5000 mAh  8.55 mm  190 g
# 2              2G, 3G, 4G, 5G         4500 mAh  8.19 mm  186 g
# 3              2G, 3G, 4G, 5G         4500 mAh  8.19 mm  186 g
# 4              5G, 4G, 3G, 2G         5000 mAh   8.2 mm  197 g
# ..                        ...              ...      ...    ...
# 966  5G, 4G VOLTE, 4G, 3G, 2G              N/A   7.8 mm  199 g
# 967              5G, 4G VOLTE         5000 mAh     9 mm  214 g
# 968  2G, 3G, 4G, 4G VOLTE, 5G         4610 mAh   8.2 mm  193 g
# 969            2G, 3G, 4G, 5G         5000 mAh  8.09 mm  186 g
# 970  5G, 4G VOLTE, 4G, 3G, 2G         5000 mAh  8.05 mm  190 g
#
# [971 rows x 31 columns]

# %%
Flipkart_df.shape
# Out:
# (971, 31)
